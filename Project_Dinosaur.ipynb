# %% [markdown]
# <a href="https://colab.research.google.com/github/BestApisit/data_viz_2022/blob/main/Project_Dinosaur.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Present Project กลุ่ม
#
# Drive :
# https://drive.google.com/drive/folders/1VXzn4IPCF0R9rsp0oO3zdKh_H6uKDbQv
#
# Dashboard :
# https://datastudio.google.com/u/0/reporting/e45d8bb5-92ce-4fde-9775-7d1d568d7e6e/page/p_20om7gqotc/edit
#
# ไฟล์นำเสนอ :
# https://www.canva.com/design/DAE70Gm59pY/YqkJeSjFuMuVsur61ax1_A/view?utm_content=DAE70Gm59pY&utm_campaign=designshare&utm_medium=link2&utm_source=sharebutton

# %%
import pandas as pd
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
path = '/content/drive/My Drive/dataviz_2021_data/Project_Dinosaur'

# %% [markdown]
# #data covid

# %% [markdown]
# * No รหัสผู้ป่วย
# * Age อายุของผู้ป่วย
# * Sex เพศผู้ป่วย
# * Nationality สัญชาติ
# * Province of isolation จังหวัดที่รักษาตัว
# * Notification Date วันที่กระทรวงได้รับรายงาน
# * Announce Date วันที่แถลงข่าว
# * Province of onset จังหวัดที่เริ่มพบว่าตัวเองมีอาการป่วย
# * District of onset อำเภอที่เริ่มพบว่าตัวเองมีอาการป่วย
# * risk สถานที่

# %% [markdown]
# ##ตารางข้อมูล covid ปี2020

# %%
data_covid2020 =  pd.read_csv(os.path.join(path,'confirmed-cases.csv'))
data_covid2020
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#            No. announce_date Notified date   sex   age Unit nationality  \
# 0            1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1            2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2            3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3            4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4            5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...        ...           ...           ...   ...   ...  ...         ...
# 839766  839767     12/8/2021     11/8/2021   ชาย  52.0   ปี         NaN
# 839767  839768     12/8/2021     11/8/2021   ชาย  34.0   ปี    Thailand
# 839768  839769     12/8/2021     11/8/2021   ชาย  31.0   ปี    Thailand
# ...

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(1)

# %%
data_covid2021_1 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-120864.csv'))
data_covid2021_1
# Out:
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0         816990     12/8/2021     11/8/2021   ชาย   7.0   ปี    Thailand
# 1         816991     12/8/2021     11/8/2021   ชาย   1.0   ปี    Thailand
# 2         816992     12/8/2021     11/8/2021   ชาย  35.0   ปี    Thailand
# 3         816993     12/8/2021     11/8/2021  หญิง  33.0   ปี    Thailand
# 4         816994     12/8/2021     11/8/2021  หญิง  14.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1042163  1859153    25/10/2021    24/10/2021   ชาย  45.0   ปี         NaN
# 1042164  1859154    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042165  1859155    25/10/2021    24/10/2021   ชาย  31.0   ปี         NaN
# 1042166  1859156    25/10/2021    24/10/2021   ชาย  24.0   ปี         NaN
# 1042167  1859157    25/10/2021    24/10/2021   ชาย  25.0   ปี         NaN
#
#         province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ##ตารางข้อมูล covid ปี2021(2)

# %%
data_covid2021_2 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-271064.csv'))
data_covid2021_2
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2882: DtypeWarning: Columns (4) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#              No. announce_date Notified date   sex   age Unit nationality  \
# 0        1859158    26/10/2021    25/10/2021   ชาย  20.0   ปี    Thailand
# 1        1859159    26/10/2021    25/10/2021  หญิง  42.0   ปี    Thailand
# 2        1859160    26/10/2021    25/10/2021  หญิง  33.0   ปี    Thailand
# 3        1859161    26/10/2021    25/10/2021  หญิง  52.0   ปี    Thailand
# 4        1859162    26/10/2021    25/10/2021  หญิง  84.0   ปี    Thailand
# ...          ...           ...           ...   ...   ...  ...         ...
# 1010454  2869612     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010455  2869613     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# 1010456  2869614     27/2/2022     26/2/2022   ชาย   NaN  NaN         NaN
# ...

# %% [markdown]
# ##ตารางข้อมูล covid ปี2022

# %%
data_covid2022 =  pd.read_csv(os.path.join(path,'confirmed-cases-since-280265.csv'))
data_covid2022
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0       2869617     28/2/2022     27/2/2022   ชาย  41.0   ปี    Thailand
# 1       2869618     28/2/2022     27/2/2022  หญิง  45.0   ปี    Thailand
# 2       2869619     28/2/2022     27/2/2022  หญิง  40.0   ปี    Thailand
# 3       2869620     28/2/2022     27/2/2022   ชาย  44.0   ปี    Thailand
# 4       2869621     28/2/2022     27/2/2022   ชาย  11.0   ปี    Thailand
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                                         risk  \
# ...

# %% [markdown]
# ##ต่อตาราง data_covid ทั้ง 4 ตาราง

# %%
data_covid = pd.concat([data_covid2020, data_covid2021_1, data_covid2021_2, data_covid2022])
data_covid
# Out:
#             No. announce_date Notified date   sex   age Unit nationality  \
# 0             1     12/1/2020           NaN  หญิง  61.0   ปี       China
# 1             2     17/1/2020           NaN  หญิง  74.0   ปี       China
# 2             3     22/1/2020           NaN  หญิง  73.0   ปี    Thailand
# 3             4     22/1/2020           NaN   ชาย  68.0   ปี       China
# 4             5     24/1/2020           NaN  หญิง  66.0   ปี       China
# ...         ...           ...           ...   ...   ...  ...         ...
# 433548  3303165     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433549  3303166     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433550  3303167     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433551  3303168     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
# 433552  3303169     18/3/2022     17/3/2022  หญิง   NaN  NaN         NaN
#
#        province_of_isolation                              risk  \
# ...

# %% [markdown]
# ###เลือกเฉพาะ column ที่ต้องการ

# %%
covid = data_covid[['announce_date','province_of_isolation']]
covid
# Out:
#        announce_date province_of_isolation
# 0          12/1/2020         กรุงเทพมหานคร
# 1          17/1/2020         กรุงเทพมหานคร
# 2          22/1/2020                นครปฐม
# 3          22/1/2020         กรุงเทพมหานคร
# 4          24/1/2020               นนทบุรี
# ...              ...                   ...
# 433548     18/3/2022         กรุงเทพมหานคร
# 433549     18/3/2022         กรุงเทพมหานคร
# 433550     18/3/2022         กรุงเทพมหานคร
# 433551     18/3/2022                 สงขลา
# 433552     18/3/2022                 สงขลา
#
# [3325951 rows x 2 columns]

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
covid.isnull().any() #ดูค่า missing ของแต่ละ column
# Out:
# announce_date            False
# province_of_isolation     True
# dtype: bool

# %% [markdown]
# ###จัดรูปแบบข้อมูล

# %%
len(set(covid['province_of_isolation'])) #ข้อมูลในคอลัมน์ province_of_isolation ต้องมี 77 ค่า
# Out:
# 81

# %%
set(covid['province_of_isolation'])
# Out:
# {nan,
#  'กทม',
#  'กระบี่',
#  'กรุงเทพมหานคร',
#  'กาญจนบุรี',
#  'กาฬสินธุ์',
#  'กำแพงเพชร',
#  'ขอนแก่น',
#  'ขอนแก่น\xa0',
#  'จันทบุรี',
#  'ฉะเชิงเทรา',
#  'ชลบุรี',
#  'ชัยนาท',
#  'ชัยภูมิ',
#  'ชุมพร',
#  'ตรัง',
#  'ตราด',
#  'ตาก',
#  'นครนายก',
#  'นครปฐม',
#  'นครพนม',
#  'นครราชสีมา',
#  'นครศรีธรรมราช',
#  'นครสวรรค์',
#  'นนทบุรี',
#  'นราธิวาส',
#  'น่าน',
#  'บึงกาฬ',
#  'บุรีรัมย์',
#  'ปทุมธานี',
#  'ประจวบคีรีขันธ์',
#  'ปราจีนบุรี',
#  'ปัตตานี',
#  'พระนครศรีอยุธยา',
#  'พะเยา',
#  'พังงา',
#  'พัทลุง',
#  'พิจิตร',
#  'พิษณุโลก',
#  'ภููเก็ต',
#  'ภูเก็ต',
#  'มหาสารคาม',
#  'มุกดาหาร',
#  'ยะลา',
#  'ยโสธร',
#  'ระนอง',
#  'ระยอง',
#  'ราชบุรี',
#  'ร้อยเอ็ด',
#  'ลพบุรี',
#  'ลำปาง',
#  'ลำพูน',
#  'ศรีสะเกษ',
#  'สกลนคร',
#  'สงขลา',
#  'สตูล',
#  'สมุทรปราการ',
#  'สมุทรสงคราม',
#  'สมุทรสาคร',
#  'สระบุรี',
#  'สระแก้ว',
#  'สิงห์บุรี',
#  'สุพรรณบุรี',
#  'สุราษฎร์ธานี',
#  'สุรินทร์',
#  'สุโขทัย',
#  'หนองคาย',
#  'หนองบัวลำภู',
#  'อำนาจเจริญ',
# ...

# %%
covid.replace({'กทม':'กรุงเทพมหานคร','ขอนแก่น\xa0':'ขอนแก่น','ภููเก็ต':'ภูเก็ต'}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
len(set(covid['province_of_isolation'])) #มีค่าที่ชื่อว่า ไม่ระบุ
# Out:
# 78

# %%
covid.isnull().any()
# Out:
# announce_date            False
# province_of_isolation     True
# dtype: bool

# %%
Covid = covid.dropna() #drop ค่า Nan ออกจากตาราง

# %%
Covid
# Out:
#        announce_date province_of_isolation
# 0          12/1/2020         กรุงเทพมหานคร
# 1          17/1/2020         กรุงเทพมหานคร
# 2          22/1/2020                นครปฐม
# 3          22/1/2020         กรุงเทพมหานคร
# 4          24/1/2020               นนทบุรี
# ...              ...                   ...
# 433548     18/3/2022         กรุงเทพมหานคร
# 433549     18/3/2022         กรุงเทพมหานคร
# 433550     18/3/2022         กรุงเทพมหานคร
# 433551     18/3/2022                 สงขลา
# 433552     18/3/2022                 สงขลา
#
# [3321995 rows x 2 columns]

# %%
import datetime
Covid = pd.DataFrame(Covid)
Covid['announce_date'] = pd.to_datetime(Covid['announce_date'], format = "%d/%m/%Y")
Covid
# Out:
#        announce_date province_of_isolation
# 0         2020-01-12         กรุงเทพมหานคร
# 1         2020-01-17         กรุงเทพมหานคร
# 2         2020-01-22                นครปฐม
# 3         2020-01-22         กรุงเทพมหานคร
# 4         2020-01-24               นนทบุรี
# ...              ...                   ...
# 433548    2022-03-18         กรุงเทพมหานคร
# 433549    2022-03-18         กรุงเทพมหานคร
# 433550    2022-03-18         กรุงเทพมหานคร
# 433551    2022-03-18                 สงขลา
# 433552    2022-03-18                 สงขลา
#
# [3321995 rows x 2 columns]

# %%
gb_covid = Covid.groupby(['announce_date','province_of_isolation']).size().reset_index(name='จำนวนผู้รักษาตัว')
gb_covid
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว
# 0        2020-01-12         กรุงเทพมหานคร                 1
# 1        2020-01-17         กรุงเทพมหานคร                 1
# 2        2020-01-22         กรุงเทพมหานคร                 1
# 3        2020-01-22                นครปฐม                 1
# 4        2020-01-24               นนทบุรี                 1
# ...             ...                   ...               ...
# 27103    2022-03-18              เพชรบุรี               355
# 27104    2022-03-18             เพชรบูรณ์               101
# 27105    2022-03-18                   เลย               139
# 27106    2022-03-18                  แพร่                73
# 27107    2022-03-18            แม่ฮ่องสอน                34
#
# [27108 rows x 3 columns]

# %% [markdown]
# #สร้างตารางภูมิภาค

# %%
data_region = {'Province':['อำนาจเจริญ','บึงกาฬ','บุรีรัมย์','ชัยภูมิ','กาฬสินธุ์','ขอนแก่น','เลย','มหาสารคาม','มุกดาหาร','นครพนม','นครราชสีมา','หนองบัวลำภู','หนองคาย','ร้อยเอ็ด','สกลนคร','ศรีสะเกษ','สุรินทร์','อุบลราชธานี','อุดรธานี','ยโสธร','เชียงใหม่','เชียงราย','ลำปาง','ลำพูน','แม่ฮ่องสอน','น่าน','พะเยา','แพร่','อุตรดิตถ์','ตาก','สุโขทัย','พิษณุโลก','พิจิตร','กำแพงเพชร','เพชรบูรณ์','นครสวรรค์','อุทัยธานี','อ่างทอง','ชัยนาท','พระนครศรีอยุธยา','กรุงเทพมหานคร','ลพบุรี','นครปฐม','นนทบุรี','ปทุมธานี','สมุทรปราการ','สมุทรสาคร','สมุทรสงคราม','สระบุรี','สิงห์บุรี','สุพรรณบุรี','นครนายก','ฉะเชิงเทรา','จันทบุรี','ชลบุรี','ปราจีนบุรี','ระยอง','สระแก้ว','ตราด','กาญจนบุรี','ราชบุรี','เพชรบุรี','ประจวบคีรีขันธ์','ชุมพร','นครศรีธรรมราช','นราธิวาส','ปัตตานี','พัทลุง','สงขลา','สุราษฎร์ธานี','ยะลา','กระบี่','พังงา','ภูเก็ต','ระนอง','สตูล','ตรัง'],
             '6 ภูมิภาค':['ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','ตะวันออกเฉียงเหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','เหนือ','ตะวันตก','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','กลาง','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันออก','ตะวันตก','ตะวันตก','ตะวันตก','ตะวันตก','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้','ใต้'],
}

# %%
data_region = pd.DataFrame.from_dict(data_region)
data_region
# Out:
#       Province           6 ภูมิภาค
# 0   อำนาจเจริญ  ตะวันออกเฉียงเหนือ
# 1       บึงกาฬ  ตะวันออกเฉียงเหนือ
# 2    บุรีรัมย์  ตะวันออกเฉียงเหนือ
# 3      ชัยภูมิ  ตะวันออกเฉียงเหนือ
# 4    กาฬสินธุ์  ตะวันออกเฉียงเหนือ
# ..         ...                 ...
# 72       พังงา                 ใต้
# 73      ภูเก็ต                 ใต้
# 74       ระนอง                 ใต้
# 75        สตูล                 ใต้
# 76        ตรัง                 ใต้
#
# [77 rows x 2 columns]

# %% [markdown]
# ##รวมตาราง covid กับตาราง ภูมิภาค
# covid กับ data_region

# %%
covid_region = gb_covid.merge(data_region,how='left',left_on='province_of_isolation',right_on = 'Province') 
covid_region
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 0        2020-01-12         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 1        2020-01-17         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 2        2020-01-22         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 3        2020-01-22                นครปฐม                 1         นครปฐม
# 4        2020-01-24               นนทบุรี                 1        นนทบุรี
# ...             ...                   ...               ...            ...
# 27103    2022-03-18              เพชรบุรี               355       เพชรบุรี
# 27104    2022-03-18             เพชรบูรณ์               101      เพชรบูรณ์
# 27105    2022-03-18                   เลย               139            เลย
# 27106    2022-03-18                  แพร่                73           แพร่
# 27107    2022-03-18            แม่ฮ่องสอน                34     แม่ฮ่องสอน
#
#                 6 ภูมิภาค
# 0                    กลาง
# ...

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
covid_region.isnull().any()
# Out:
# announce_date            False
# province_of_isolation    False
# จำนวนผู้รักษาตัว         False
# Province                 False
# 6 ภูมิภาค                False
# dtype: bool

# %% [markdown]
# #นำเข้าข้อมูลที่เลือกเอง
# การเดินทางของประชาชนในช่วงการแพร่ระบาดของเชื้อไวรัส COVID-19
# ที่มา : https://datagov.mot.go.th/dataset/covid-19 (กระทรวงคมนาคม)

# %%
passenger =  pd.read_csv(os.path.join(path,'passenger-covid19.csv'))
passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0     1/1/2020   1,483,255     885,353     272,578        102,678
# 1     2/1/2020   1,705,026   1,269,207     291,990        104,613
# 2     3/1/2020   1,752,572   1,366,412     301,260        100,575
# 3     4/1/2020   1,576,146   1,027,281     271,171        100,852
# 4     5/1/2020   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805  16/3/2022     641,639     685,639      81,496         50,761
# 806  17/3/2022     657,339     676,376      93,516         53,177
# 807  18/3/2022     646,203     729,250     104,801         63,230
# 808  19/3/2022     555,727     580,102      93,046         58,347
# 809  20/3/2022     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน) รถส่วนบุคคล เข้า - ออก กทม. (คัน)  \
# 0                2,743,864                         2,310,406
# ...

# %%
import datetime
passenger = pd.DataFrame(passenger)
passenger['วันที่'] = pd.to_datetime(passenger['วันที่'], format = "%d/%m/%Y")
passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0   2020-01-01   1,483,255     885,353     272,578        102,678
# 1   2020-01-02   1,705,026   1,269,207     291,990        104,613
# 2   2020-01-03   1,752,572   1,366,412     301,260        100,575
# 3   2020-01-04   1,576,146   1,027,281     271,171        100,852
# 4   2020-01-05   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805 2022-03-16     641,639     685,639      81,496         50,761
# 806 2022-03-17     657,339     676,376      93,516         53,177
# 807 2022-03-18     646,203     729,250     104,801         63,230
# 808 2022-03-19     555,727     580,102      93,046         58,347
# 809 2022-03-20     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน) รถส่วนบุคคล เข้า - ออก กทม. (คัน)  \
# 0                2,743,864                         2,310,406
# ...

# %%
import datetime
passenger = pd.DataFrame(passenger)
passenger['วันที่'] = pd.to_datetime(passenger['วันที่'], format = "%d/%m/%Y")
passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0   2020-01-01   1,483,255     885,353     272,578        102,678
# 1   2020-01-02   1,705,026   1,269,207     291,990        104,613
# 2   2020-01-03   1,752,572   1,366,412     301,260        100,575
# 3   2020-01-04   1,576,146   1,027,281     271,171        100,852
# 4   2020-01-05   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805 2022-03-16     641,639     685,639      81,496         50,761
# 806 2022-03-17     657,339     676,376      93,516         53,177
# 807 2022-03-18     646,203     729,250     104,801         63,230
# 808 2022-03-19     555,727     580,102      93,046         58,347
# 809 2022-03-20     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน) รถส่วนบุคคล เข้า - ออก กทม. (คัน)  \
# 0                2,743,864                         2,310,406
# ...

# %% [markdown]
# ###เลือกเฉพาะ column ที่ต้องการ

# %%
Passenger = passenger[['วันที่','ทางถนน (คน)','ทางราง (คน)','ทางน้ำ (คน)', 'ทางอากาศ* (คน)', 'รวมประชาชนเดินทาง (คน)']]
Passenger
# Out:
#         วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# 0   2020-01-01   1,483,255     885,353     272,578        102,678
# 1   2020-01-02   1,705,026   1,269,207     291,990        104,613
# 2   2020-01-03   1,752,572   1,366,412     301,260        100,575
# 3   2020-01-04   1,576,146   1,027,281     271,171        100,852
# 4   2020-01-05   1,565,134     915,425     254,176        100,784
# ..         ...         ...         ...         ...            ...
# 805 2022-03-16     641,639     685,639      81,496         50,761
# 806 2022-03-17     657,339     676,376      93,516         53,177
# 807 2022-03-18     646,203     729,250     104,801         63,230
# 808 2022-03-19     555,727     580,102      93,046         58,347
# 809 2022-03-20     495,000     455,593      84,072         64,442
#
#     รวมประชาชนเดินทาง (คน)
# 0                2,743,864
# 1                3,370,836
# 2                3,520,819
# 3                2,975,450
# 4                2,835,519
# ...

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
Passenger.isnull().any() #ดูค่า missing ของแต่ละ column
# Out:
# วันที่                    False
# ทางถนน (คน)               False
# ทางราง (คน)               False
# ทางน้ำ (คน)               False
# ทางอากาศ* (คน)            False
# รวมประชาชนเดินทาง (คน)    False
# dtype: bool

# %% [markdown]
# ##รวมตาราง covid_region กับตาราง Passenger

# %%
all_data = covid_region.merge(Passenger,how='left',left_on='announce_date',right_on='วันที่')
all_data
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 0        2020-01-12         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 1        2020-01-17         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 2        2020-01-22         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 3        2020-01-22                นครปฐม                 1         นครปฐม
# 4        2020-01-24               นนทบุรี                 1        นนทบุรี
# ...             ...                   ...               ...            ...
# 27103    2022-03-18              เพชรบุรี               355       เพชรบุรี
# 27104    2022-03-18             เพชรบูรณ์               101      เพชรบูรณ์
# 27105    2022-03-18                   เลย               139            เลย
# 27106    2022-03-18                  แพร่                73           แพร่
# 27107    2022-03-18            แม่ฮ่องสอน                34     แม่ฮ่องสอน
#
# ...

# %% [markdown]
# ##ตรวจสอบค่า Missing

# %%
all_data.isnull().any() #ดูค่า missing ของแต่ละ column
# Out:
# announce_date             False
# province_of_isolation     False
# จำนวนผู้รักษาตัว          False
# Province                  False
# 6 ภูมิภาค                 False
# วันที่                    False
# ทางถนน (คน)               False
# ทางราง (คน)               False
# ทางน้ำ (คน)               False
# ทางอากาศ* (คน)            False
# รวมประชาชนเดินทาง (คน)    False
# dtype: bool

# %% [markdown]
# ##แบ่งข้อมูลไปใช้งาน

# %%
covid2020 = all_data[(all_data['announce_date'] >= '2020-01-12') & (all_data['announce_date'] <= '2020-12-31')] #ข้อมูลปี 2020
covid2020
# Out:
#      announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 0       2020-01-12         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 1       2020-01-17         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 2       2020-01-22         กรุงเทพมหานคร                 1  กรุงเทพมหานคร
# 3       2020-01-22                นครปฐม                 1         นครปฐม
# 4       2020-01-24               นนทบุรี                 1        นนทบุรี
# ...            ...                   ...               ...            ...
# 1257    2020-12-31               ราชบุรี                 1        ราชบุรี
# 1258    2020-12-31           สมุทรปราการ                 8    สมุทรปราการ
# 1259    2020-12-31           สมุทรสงคราม                 1    สมุทรสงคราม
# 1260    2020-12-31             สมุทรสาคร                28      สมุทรสาคร
# 1261    2020-12-31               หนองคาย                 1        หนองคาย
#
#                6 ภูมิภาค     วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน)  \
# ...

# %%
covid2021_1 = all_data[(all_data['announce_date'] >= '2021-01-01') & (all_data['announce_date'] <= '2021-03-31')] #ข้อมูลไตรมาสแรกของปี 2021
covid2021_1
# Out:
#      announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 1262    2021-01-01         กรุงเทพมหานคร                26  กรุงเทพมหานคร
# 1263    2021-01-01              จันทบุรี                29       จันทบุรี
# 1264    2021-01-01            ฉะเชิงเทรา                 1     ฉะเชิงเทรา
# 1265    2021-01-01                ชลบุรี                51         ชลบุรี
# 1266    2021-01-01                  ตราด                 7           ตราด
# ...            ...                   ...               ...            ...
# 2145    2021-03-31                ชลบุรี                 4         ชลบุรี
# 2146    2021-03-31                   ตาก                 2            ตาก
# 2147    2021-03-31              นราธิวาส                 1       นราธิวาส
# 2148    2021-03-31           สมุทรปราการ                 5    สมุทรปราการ
# 2149    2021-03-31             สมุทรสาคร                11      สมุทรสาคร
#
#      6 ภูมิภาค     วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน) ทางอากาศ* (คน)  \
# ...

# %%
covid2021_2 = all_data[(all_data['announce_date'] >= '2021-04-01') & (all_data['announce_date'] <= '2021-06-30')] #ข้อมูลไตรมาสสองของปี 2021
covid2021_2
# Out:
#      announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 2150    2021-04-01         กรุงเทพมหานคร                11  กรุงเทพมหานคร
# 2151    2021-04-01                ชลบุรี                 1         ชลบุรี
# 2152    2021-04-01           สมุทรปราการ                 3    สมุทรปราการ
# 2153    2021-04-01             สมุทรสาคร                11      สมุทรสาคร
# 2154    2021-04-02         กรุงเทพมหานคร                24  กรุงเทพมหานคร
# ...            ...                   ...               ...            ...
# 7280    2021-06-30              เชียงราย                28       เชียงราย
# 7281    2021-06-30             เชียงใหม่                 4      เชียงใหม่
# 7282    2021-06-30              เพชรบุรี                75       เพชรบุรี
# 7283    2021-06-30             เพชรบูรณ์                15      เพชรบูรณ์
# 7284    2021-06-30                   เลย                 8            เลย
#
#                6 ภูมิภาค     วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน)  \
# ...

# %%
covid2021_3 = all_data[(all_data['announce_date'] >= '2021-07-01') & (all_data['announce_date'] <= '2021-09-30')] #ข้อมูลไตรมาสสามของปี 2021
covid2021_3
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 7285     2021-07-01                กระบี่                 2         กระบี่
# 7286     2021-07-01         กรุงเทพมหานคร              1974  กรุงเทพมหานคร
# 7287     2021-07-01             กาญจนบุรี                19      กาญจนบุรี
# 7288     2021-07-01             กาฬสินธุ์                10      กาฬสินธุ์
# 7289     2021-07-01             กำแพงเพชร                 3      กำแพงเพชร
# ...             ...                   ...               ...            ...
# 14313    2021-09-30              เพชรบุรี               115       เพชรบุรี
# 14314    2021-09-30             เพชรบูรณ์                61      เพชรบูรณ์
# 14315    2021-09-30                   เลย                21            เลย
# 14316    2021-09-30                  แพร่                16           แพร่
# 14317    2021-09-30            แม่ฮ่องสอน                30     แม่ฮ่องสอน
#
# ...

# %%
covid2021_4 = all_data[(all_data['announce_date'] >= '2021-10-01') & (all_data['announce_date'] <= '2021-12-31')] #ข้อมูลไตรมาสสี่ของปี 2021
covid2021_4
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 14318    2021-10-01                กระบี่               103         กระบี่
# 14319    2021-10-01         กรุงเทพมหานคร              1434  กรุงเทพมหานคร
# 14320    2021-10-01             กาญจนบุรี               177      กาญจนบุรี
# 14321    2021-10-01             กาฬสินธุ์                14      กาฬสินธุ์
# 14322    2021-10-01             กำแพงเพชร                15      กำแพงเพชร
# ...             ...                   ...               ...            ...
# 21187    2021-12-31              เพชรบุรี                17       เพชรบุรี
# 21188    2021-12-31             เพชรบูรณ์                46      เพชรบูรณ์
# 21189    2021-12-31                   เลย                 8            เลย
# 21190    2021-12-31                  แพร่                 2           แพร่
# 21191    2021-12-31            แม่ฮ่องสอน                22     แม่ฮ่องสอน
#
# ...

# %%
covid2022_1 = all_data[(all_data['announce_date'] >= '2022-01-01') & (all_data['announce_date'] <= '2022-01-31')] #ข้อมูลเดือนมกราคมปี 2022
covid2022_1
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 21192    2022-01-01                กระบี่                35         กระบี่
# 21193    2022-01-01         กรุงเทพมหานคร               454  กรุงเทพมหานคร
# 21194    2022-01-01             กาญจนบุรี                28      กาญจนบุรี
# 21195    2022-01-01             กาฬสินธุ์                55      กาฬสินธุ์
# 21196    2022-01-01             กำแพงเพชร                 7      กำแพงเพชร
# ...             ...                   ...               ...            ...
# 23566    2022-01-31              เพชรบุรี                74       เพชรบุรี
# 23567    2022-01-31             เพชรบูรณ์                46      เพชรบูรณ์
# 23568    2022-01-31                   เลย                91            เลย
# 23569    2022-01-31                  แพร่                24           แพร่
# 23570    2022-01-31            แม่ฮ่องสอน                 6     แม่ฮ่องสอน
#
# ...

# %%
covid2022_2 = all_data[(all_data['announce_date'] >= '2022-02-01') & (all_data['announce_date'] <= '2022-02-28')] #ข้อมูลเดือนกุมภาพันธ์ปี 2022
covid2022_2
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 23571    2022-02-01                กระบี่                42         กระบี่
# 23572    2022-02-01         กรุงเทพมหานคร              1269  กรุงเทพมหานคร
# 23573    2022-02-01             กาญจนบุรี                95      กาญจนบุรี
# 23574    2022-02-01             กาฬสินธุ์                34      กาฬสินธุ์
# 23575    2022-02-01             กำแพงเพชร                 7      กำแพงเพชร
# ...             ...                   ...               ...            ...
# 25720    2022-02-28              เพชรบุรี               200       เพชรบุรี
# 25721    2022-02-28             เพชรบูรณ์                61      เพชรบูรณ์
# 25722    2022-02-28                   เลย                99            เลย
# 25723    2022-02-28                  แพร่                77           แพร่
# 25724    2022-02-28            แม่ฮ่องสอน                11     แม่ฮ่องสอน
#
# ...

# %%
covid2022_3 = all_data[all_data['announce_date'] >= '2022-03-01'] #ข้อมูลวันที่ 1- 18 เดือนมีนาคม ปี 2022
covid2022_3
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 25725    2022-03-01                กระบี่               104         กระบี่
# 25726    2022-03-01         กรุงเทพมหานคร              2802  กรุงเทพมหานคร
# 25727    2022-03-01             กาญจนบุรี               189      กาญจนบุรี
# 25728    2022-03-01             กาฬสินธุ์               142      กาฬสินธุ์
# 25729    2022-03-01             กำแพงเพชร               224      กำแพงเพชร
# ...             ...                   ...               ...            ...
# 27103    2022-03-18              เพชรบุรี               355       เพชรบุรี
# 27104    2022-03-18             เพชรบูรณ์               101      เพชรบูรณ์
# 27105    2022-03-18                   เลย               139            เลย
# 27106    2022-03-18                  แพร่                73           แพร่
# 27107    2022-03-18            แม่ฮ่องสอน                34     แม่ฮ่องสอน
#
# ...

# %% [markdown]
# ##เลือกทำข้อมูลวันที่ 29 ธันวาคม 2021 - 4 มกราคม 2022 และ 29 ธันวาคม 2020 - 4 มกราคม 2021
# ซึ่งเป็นข้อมูล 7 วันอันตรายช่วงปีใหม่

# %%
datacovid1 = all_data[(all_data['announce_date'] >= '2020-12-29') & (all_data['announce_date'] <= '2021-01-04')]
datacovid1
# Out:
#      announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 1215    2020-12-29         กรุงเทพมหานคร                21  กรุงเทพมหานคร
# 1216    2020-12-29              จันทบุรี                 3       จันทบุรี
# 1217    2020-12-29                ชลบุรี                32         ชลบุรี
# 1218    2020-12-29                นครปฐม                15         นครปฐม
# 1219    2020-12-29            นครราชสีมา                 1     นครราชสีมา
# ...            ...                   ...               ...            ...
# 1321    2021-01-04           สมุทรสงคราม                 2    สมุทรสงคราม
# 1322    2021-01-04             สมุทรสาคร               541      สมุทรสาคร
# 1323    2021-01-04          สุราษฎร์ธานี                 1   สุราษฎร์ธานี
# 1324    2021-01-04               อ่างทอง                12        อ่างทอง
# 1325    2021-01-04              เพชรบุรี                 1       เพชรบุรี
#
#                6 ภูมิภาค     วันที่ ทางถนน (คน) ทางราง (คน) ทางน้ำ (คน)  \
# ...

# %%
datacovid2 = all_data[(all_data['announce_date'] >= '2021-12-29') & (all_data['announce_date'] <= '2022-01-04')]
datacovid2
# Out:
#       announce_date province_of_isolation  จำนวนผู้รักษาตัว       Province  \
# 20967    2021-12-29                กระบี่                37         กระบี่
# 20968    2021-12-29         กรุงเทพมหานคร               407  กรุงเทพมหานคร
# 20969    2021-12-29             กาญจนบุรี                28      กาญจนบุรี
# 20970    2021-12-29             กาฬสินธุ์                65      กาฬสินธุ์
# 20971    2021-12-29             กำแพงเพชร                12      กำแพงเพชร
# ...             ...                   ...               ...            ...
# 21489    2022-01-04              เพชรบุรี                 3       เพชรบุรี
# 21490    2022-01-04             เพชรบูรณ์                23      เพชรบูรณ์
# 21491    2022-01-04                   เลย                 5            เลย
# 21492    2022-01-04                  แพร่                10           แพร่
# 21493    2022-01-04            แม่ฮ่องสอน                10     แม่ฮ่องสอน
#
# ...

# %% [markdown]
# #โหลดข้อมูลออกไปใช้งาน

# %%
datacovid1.to_csv('datacovid1.csv',index=False)

# %%
datacovid2.to_csv('datacovid2.csv',index=False)
