# %% [markdown]
# <a href="https://colab.research.google.com/github/BestApisit/data_viz_2022/blob/main/Final_fustet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Load data

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1= pd.read_csv('/content/drive/My Drive/dataviz_2021_data/Final/alldb.csv')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data1 ## แสดงข้อมูล
# Out:
#        Unnamed: 0           user                                    RowKey  \
# 0               0           test                                       NaN
# 1               1          04857      136FD222-FD9F-4E54-AE1F-7282A276B085
# 2               2            NaN  1E6D3D62-4C8A-4F8E-90D1-0DC5BC2752DF.png
# 3               3  3450101576642      2D331FB0-CBA2-4586-A5B0-CB3CF44DD9FE
# 4               4  3450101576642      45197AF7-7CB4-470C-9ABB-37C092BD6B21
# ...           ...            ...                                       ...
# 40030       40030            NaN      6B5FA20F-190E-4021-8547-C12308024C6C
# 40031       40031            NaN      F48C51C0-A345-40D6-93F4-46213267E1B1
# 40032       40032            NaN      A986BDAA-6D7C-4017-8E62-A3C104E946B9
# 40033       40033            NaN                            bbuogxulur.png
# 40034       40034            NaN                            zttpqogiso.png
#
#       care        date   ov             phone   site      time  \
# ...

# %%
data2= pd.read_excel('/content/drive/MyDrive/dataviz_2021_data/Final/hospital_list.xlsx')  ## สร้างตัวแปร รับค่าข้อมูลที่อยู่ใน Google drive
data2 ## แสดงข้อมูล
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %% [markdown]
# # Data processing

# %% [markdown]
# ## Data 1

# %% [markdown]
# ### Data1 clean1

# %%
TF1=list() ## กำหนด TF ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in data1.iterrows(): ## loop each_row ใน data1
    if len(str(each_row[1]['user']))== 5 : #สร้างเงื่อนไข user ที่มีจำนวนตัวอักษรเท่ากับ 5
        if str(each_row[1]['user']) <= '99999' : #หาก user มีค่า น้อยกว่า 100000
            TF1.append(True) ## หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน TF
        elif str(each_row[1]['user']) >= '99999' : #หาก user มีค่า มากกว่า 100000
            TF1.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF
    else:
        TF1.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF

data1[TF1] ## แสดงผล
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
# 40017       40017  12345                        zgvicawbkg.png  NaN
#
#              date   ov             phone   site      time  \
# 1      2022-02-24  NaN        iPhone10,4  05310  10:50:32
# ...

# %%
df1 =data1[TF1]

# %%
df1_clean = df1[df1['user']!= '6724-']  ##พบค่าผิดปกติ คือ 6724- จึงทำการตัดออก

# %% [markdown]
# ### Data 1 clean2

# %%
TF2=list() ## กำหนด TF ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in df1_clean.iterrows(): ## loop each_row ใน data1
    if len(str(each_row[1]['site']))== 5 : #สร้างเงื่อนไข user ที่มีจำนวนตัวอักษรเท่ากับ 5
        if str(each_row[1]['site']) <= '99999' : #หาก user มีค่า น้อยกว่า 100000
            TF2.append(True) ## หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน TF
        elif str(each_row[1]['site']) >= '99999' : #หาก user มีค่า มากกว่า 100000
            TF2.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF
    else:
        TF2.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF

df1_clean[TF2] ## แสดงผล
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 1               1  04857  136FD222-FD9F-4E54-AE1F-7282A276B085  NaN
# 5               5  08777  472EED3E-E2A7-4551-9249-D87747C68AFD  NaN
# 7               7  04857  73E96EE6-7660-4204-9914-92112603C514  NaN
# 11             11  08777  C23A546B-EB6E-4DB4-93FA-2F9A7A85AEE9  NaN
# 12             12  11111  C42C6F97-4388-4C03-A0AB-84F21FAED2C2  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#              date   ov             phone   site      time  \
# 1      2022-02-24  NaN        iPhone10,4  05310  10:50:32
# ...

# %%
df1_clean2 = df1_clean[TF2]

# %% [markdown]
# ### Data 1 clean 3

# %%
TF3=list() ## กำหนด TF ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in df1_clean2.iterrows(): ## loop each_row ใน data1
    if len(str(each_row[1]['PartitionKey']))== 5 : #สร้างเงื่อนไข user ที่มีจำนวนตัวอักษรเท่ากับ 5
        if str(each_row[1]['PartitionKey']) <= '99999' :  #หาก user มีค่า น้อยกว่า 100000
            TF3.append(True) ## หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน TF
        elif str(each_row[1]['PartitionKey']) >= '99999' : #หาก user มีค่า มากกว่า 100000
            TF3.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF
    else:
        TF3.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF

df1_clean2[TF3] ## แสดงผล
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 185           185  85879                        shmpdrmtgc.png  NaN
# 190           190  06223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#              date ov              phone   site      time  \
# 185    2022-03-24  0       OPPO CPH2293  05194  13:08:39
# ...

# %% [markdown]
# ### Data missing

# %%
data1_no_dropna = df1_clean2[TF3]

# %%
data1_no_dropna
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 185           185  85879                        shmpdrmtgc.png  NaN
# 190           190  06223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#              date ov              phone   site      time  \
# 185    2022-03-24  0       OPPO CPH2293  05194  13:08:39
# ...

# %%
data1_dropna =data1_no_dropna.dropna(subset=['user','site','PartitionKey'])  ## dropna เฉพาะคอลัมน์  'user','site','PartitionKey'
data1_dropna
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 185           185  85879                        shmpdrmtgc.png  NaN
# 190           190  06223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#              date ov              phone   site      time  \
# 185    2022-03-24  0       OPPO CPH2293  05194  13:08:39
# ...

# %%
data1_dropna.isnull().any() ## เช็คค่า missing
# Out:
# Unnamed: 0      False
# user            False
# RowKey          False
# care             True
# date             True
# ov               True
# phone           False
# site            False
# time             True
# urine            True
# pid              True
# PartitionKey    False
# title            True
# age              True
# dtype: bool

# %% [markdown]
# ### out of unique data

# %%
data1_use_1=data1_dropna[data1_dropna['site']!='043.1']  ##แก้ไขค่าผิดปกติ
data1_use_1
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 185           185  85879                        shmpdrmtgc.png  NaN
# 190           190  06223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#              date ov              phone   site      time  \
# 185    2022-03-24  0       OPPO CPH2293  05194  13:08:39
# ...

# %%
data1_use=data1_use_1[data1_use_1['PartitionKey']!='002.5'] ##แก้ไขค่าผิดปกติ
data1_use
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 185           185  85879                        shmpdrmtgc.png  NaN
# 190           190  06223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#              date ov              phone   site      time  \
# 185    2022-03-24  0       OPPO CPH2293  05194  13:08:39
# ...

# %% [markdown]
# ## Data 2

# %% [markdown]
# ### Data2 clean1

# %%
TF4=list() ## กำหนด TF ให้เป็น list ว่าง เพื่อใช้เติมค่า loop
for each_row in data2.iterrows(): ## loop each_row ใน data1
    if len(str(each_row[1]['hcode']))== 5 : #สร้างเงื่อนไข user ที่มีจำนวนตัวอักษรเท่ากับ 5
        if str(each_row[1]['hcode']) <= '99999' :  #หาก user มีค่า น้อยกว่า 100000
            TF4.append(True) ## หากเงื่อนไขถูกต้องให้เพิ่มเข้าไปใน TF
        elif str(each_row[1]['hcode']) >= '99999' : #หาก user มีค่า มากกว่า 100000
            TF4.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF
    else:
        TF4.append(False) ## หากเงื่อนไขไม่ถูกต้อง ไม่ให้เพิ่มเข้าไปใน TF

data2[TF4] ## แสดงผล
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %%
data2_clean=data2[TF4]

# %% [markdown]
# ### out of unique data

# %%
data2_use1=data2_clean[data2_clean['hcode']!='2475x'] ##แก้ไขค่าผิดปกติ
data2_use1
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %%
data2_use=data2_use1[data2_use1['hcode']!='2560x'] ##แก้ไขค่าผิดปกติ
data2_use
# Out:
#        hcode                                               name  zone_code  \
# 0      00001                สำนักงานสาธารณสุขจังหวัดสมุทรปราการ          6
# 1      00002                    สำนักงานสาธารณสุขจังหวัดนนทบุรี          4
# 2      00003                   สำนักงานสาธารณสุขจังหวัดปทุมธานี          4
# 3      00004            สำนักงานสาธารณสุขจังหวัดพระนครศรีอยุธยา          4
# 4      00005                    สำนักงานสาธารณสุขจังหวัดอ่างทอง          4
# ...      ...                                                ...        ...
# 17098  99990  ศูนย์สุขภาพชุมชนโรงพยาบาลอุตรดิตถ์(สาขา 2 วัดท...          2
# 17099  99991                   ศูนย์สุขภาพชุมชนโรงพยาบาลกุยบุรี          5
# 17100  99993                        ศูนย์สุขภาพชุมชนตำบลวัดเพลง          5
# 17101  99996                        คลินิกทันตกรรม สสจ.ศรีสะเกษ         10
# 17102  99998                          ศูนย์สุขภาพชุมชนตำบลบางแพ          5
#
# ...

# %% [markdown]
# # Change dtype

# %% [markdown]
# ##Data 1

# %%
data1_use.info() ##เช็คข้อมูล dtype แต่ละคอลัมน์
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38386 entries, 185 to 39816
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    38386 non-null  int64
#  1   user          38386 non-null  object
#  2   RowKey        38386 non-null  object
#  3   care          0 non-null      object
#  4   date          38104 non-null  object
#  5   ov            38175 non-null  object
#  6   phone         38386 non-null  object
#  7   site          38386 non-null  object
#  8   time          38103 non-null  object
#  9   urine         38272 non-null  object
#  10  pid           0 non-null      object
#  11  PartitionKey  38386 non-null  object
#  12  title         37976 non-null  object
#  13  age           37878 non-null  object
# dtypes: int64(1), object(13)
# memory usage: 4.4+ MB

# %%
data1_use['time'] = pd.to_datetime(data1_use['time'],format='%H:%M%:%S',errors='ignore') ##แก้ dtype คอลัมน์ time
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use['date'] = pd.to_datetime(data1_use['date'],format='%Y/%m/%d') ##แก้ dtype คอลัมน์ date
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use['phone']=data1_use['phone'].astype('string') ##แก้ dtype คอลัมน์ phone
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use['urine']=data1_use['urine'].astype('string') ##แก้ dtype คอลัมน์ urine
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use['RowKey']=data1_use['RowKey'].astype('string') ##แก้ dtype คอลัมน์ RowKey
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use['user']=data1_use['user'].astype('int64') ##แก้ dtype คอลัมน์ user
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use['site']=data1_use['site'].astype('int64') ##แก้ dtype คอลัมน์ site
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use['PartitionKey']=data1_use['PartitionKey'].astype('int64') ##แก้ dtype คอลัมน์ PartitionKey
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data1_use.info() ## เช็คข้อมูลแต่ละคอลัมน์
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38386 entries, 185 to 39816
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    38386 non-null  int64
#  1   user          38386 non-null  int64
#  2   RowKey        38386 non-null  string
#  3   care          0 non-null      object
#  4   date          38104 non-null  datetime64[ns]
#  5   ov            38175 non-null  object
#  6   phone         38386 non-null  string
#  7   site          38386 non-null  int64
#  8   time          38103 non-null  object
#  9   urine         38272 non-null  string
#  10  pid           0 non-null      object
#  11  PartitionKey  38386 non-null  int64
#  12  title         37976 non-null  object
#  13  age           37878 non-null  object
# dtypes: datetime64[ns](1), int64(4), object(6), string(3)
# memory usage: 4.4+ MB

# %%
data1_use ## แสดงตาราง
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 185           185  85879                        shmpdrmtgc.png  NaN
# 190           190   6223                        kfpwuaqldj.png  NaN
# 191           191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 192           192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 193           193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# ...           ...    ...                                   ...  ...
# 39812       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 39813       39813  99999                        lnlohgqckf.png  NaN
# 39814       39814  99999                        vkdocpmjiv.png  NaN
# 39815       39815  99999                        vrvyfnvayq.png  NaN
# 39816       39816  99999                        zuhbtvyrce.png  NaN
#
#             date ov              phone   site      time                 urine  \
# ...

# %% [markdown]
# ## Data 2

# %%
data2_use.info() ## เช็คข้อมูลแต่ละคอลัมน์
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 17101 entries, 0 to 17102
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   hcode          17101 non-null  object
#  1   name           17100 non-null  object
#  2   zone_code      17101 non-null  int64
#  3   zone_name      17097 non-null  object
#  4   provincecode   17100 non-null  float64
#  5   province       17101 non-null  object
#  6   amphurcode     17099 non-null  float64
#  7   amphur         17099 non-null  object
#  8   tamboncode     16933 non-null  float64
#  9   tambon         16892 non-null  object
#  10  code4          17100 non-null  float64
#  11  name5          17098 non-null  object
#  12  code9          11809 non-null  float64
#  13  name10         11809 non-null  object
#  14  short_thai     17095 non-null  object
#  15  short_english  17095 non-null  object
# dtypes: float64(5), int64(1), object(10)
# memory usage: 2.2+ MB

# %%
data2_use['hcode']=data2_use['hcode'].astype('int64') ## แก้ dtype คอลัมน์ hcode
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Merge Table

# %%
df_merge = data1_use.merge(data2_use,how='left',left_on='site',right_on='hcode') ## เชื่อมตาราง data1_use กับ data2_use ด้วยคีย์ site และ hcode
df_merge  ## แสดงตาราง
# Out:
#        Unnamed: 0   user                                RowKey care  \
# 0             185  85879                        shmpdrmtgc.png  NaN
# 1             190   6223                        kfpwuaqldj.png  NaN
# 2             191  12015  00859DB9-1BD9-4825-B246-3DC25EFD1924  NaN
# 3             192  91811  1376ACA2-AFA5-4457-967A-D2FCF908E6A5  NaN
# 4             193  95821  1914EE67-CD8F-47EE-A968-2772911AA5DF  NaN
# ...           ...    ...                                   ...  ...
# 38381       39812  99999  F45E78D3-7D89-47A3-8207-C705377E0E0A  NaN
# 38382       39813  99999                        lnlohgqckf.png  NaN
# 38383       39814  99999                        vkdocpmjiv.png  NaN
# 38384       39815  99999                        vrvyfnvayq.png  NaN
# 38385       39816  99999                        zuhbtvyrce.png  NaN
#
#             date ov              phone   site      time                 urine  \
# ...

# %% [markdown]
# # Export

# %%
data_processing=df_merge[['user','hcode','name','province','amphur','date','time','ov','phone','urine']]  ##เลือกคอลัมน์ที่ต้องการ
data_processing  ## แสดงตาราง
# Out:
#         user    hcode                                               name  \
# 0      85879   5194.0  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านหนองหว้า ตำบลกก...
# 1       6223  13777.0            โรงพยาบาลศรีนครินทร์ มหาวิทยาลัยขอนแก่น
# 2      12015   6307.0  โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านเกาะ  ตำบลบ้านดารา
# 3      91811   5328.0        โรงพยาบาลส่งเสริมสุขภาพตำบลบ้านโคกประสิทธิ์
# 4      95821   6302.0                 โรงพยาบาลส่งเสริมสุขภาพตำบลสองห้อง
# ...      ...      ...                                                ...
# 38381  99999      NaN                                                NaN
# 38382  99999      NaN                                                NaN
# 38383  99999      NaN                                                NaN
# 38384  99999      NaN                                                NaN
# 38385  99999      NaN                                                NaN
#
#         province        amphur       date      time ov              phone  \
# ...

# %%
data_processing.shape  ##เช็คขนาดของตาราง
# Out:
# (38386, 10)

# %%
data_complete = data_processing.dropna() ##กำจัด missing
data_complete.shape ##เช็คขนาดของตาราง
# Out:
# (37825, 10)

# %%
print(f'ก่อน dropna {data_processing.shape}') ##เช็คขนาดของตารางเดิม
print(f'ก่อน dropna{data_complete.shape}') ##เช็คขนาดของตารางใหม่
# Out:
# ก่อน dropna (38386, 10)
# ก่อน dropna(37825, 10)

# %%
data_complete.to_csv('Data_complete.csv',encoding='utf-8') ## Export ไฟล์

# %% [markdown]
# # Dashboard's Link

# %% [markdown]
# https://datastudio.google.com/reporting/aa2b12ae-e4f4-40d8-aff7-b55b1265c678
